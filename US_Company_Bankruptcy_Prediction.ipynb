# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/content/american_bankruptcy.csv',",")
cols=['company_name','status_label','year','Current assets','Cost of goods sold','Depreciation and amortization','EBITDA','Inventory','Net Income','Total Receivables','Market value','Net sales','Total assets','Total Long-term debt','EBIT','Gross Profit','Total Current Liabilities','Retained Earnings','Total Revenue','Total Liabilities','Total Operating Expenses']
# Out:
# <ipython-input-140-f9966e71019d>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df=pd.read_csv('/content/drive/MyDrive/content/american_bankruptcy.csv',",")

# %%
df.head()
# Out:
#   company_name status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...        X9      X10      X11     X12      X13      X14  \
# 0  35.163  128.348  ...  1024.333  740.998  180.447  70.658  191.226  163.816
# 1  18.531  115.187  ...   874.255  701.854  179.987  45.790  160.444  125.392
# 2 -58.939   77.528  ...   638.721  710.199  217.699   4.711  112.244  150.464
# 3 -12.410   66.322  ...   606.337  686.621  164.658   3.573  109.590  203.575
# 4   3.504  104.661  ...   651.958  709.292  248.666  20.811  128.656  131.261
#
# ...

# %%
# df.columns=cols

# %%
# data=tf.constant(df)

# %% [markdown]
# # With SckitLearn

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-144-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
x=df.drop(['status_label','company_name','year'],axis=1)
y=df['status_label']

# %%
x.shape
# Out:
# (78682, 18)

# %%
y.shape
# Out:
# (78682,)

# %%
y.shape
# Out:
# (78682,)

# %%
x.isna().sum()
# Out:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
# X6     0
# X7     0
# X8     0
# X9     0
# X10    0
# X11    0
# X12    0
# X13    0
# X14    0
# X15    0
# X16    0
# X17    0
# X18    0
# dtype: int64

# %%
x.dtypes
# Out:
# X1     float64
# X2     float64
# X3     float64
# X4     float64
# X5     float64
# X6     float64
# X7     float64
# X8     float64
# X9     float64
# X10    float64
# X11    float64
# X12    float64
# X13    float64
# X14    float64
# X15    float64
# X16    float64
# X17    float64
# X18    float64
# dtype: object

# %%
x.describe()
# Out:
#                   X1             X2            X3            X4            X5  \
# count   78682.000000   78682.000000  78682.000000  78682.000000  78682.000000
# mean      880.362485    1594.529029    121.234256    376.759424    201.605717
# std      3928.564794    8930.484664    652.376804   2012.023142   1060.766096
# min        -7.760000    -366.645000      0.000000 -21913.000000      0.000000
# 25%        18.924000      17.038250      1.192000     -0.811000      0.000000
# 50%       100.449500     103.661000      7.929500     15.034500      7.023000
# 75%       431.526750     634.548000     47.971750    139.655250     74.747250
# max    169662.000000  374623.000000  28430.000000  81730.000000  62567.000000
#
#                   X6            X7            X8             X9  \
# count   78682.000000  78682.000000  7.868200e+04   78682.000000
# mean      129.382453    286.832743  3.414355e+03    2364.019706
# std      1265.532022   1335.978571  1.841410e+04   11950.068842
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78682 entries, 0 to 78681
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      78682 non-null  float64
#  1   X2      78682 non-null  float64
#  2   X3      78682 non-null  float64
#  3   X4      78682 non-null  float64
#  4   X5      78682 non-null  float64
#  5   X6      78682 non-null  float64
#  6   X7      78682 non-null  float64
#  7   X8      78682 non-null  float64
#  8   X9      78682 non-null  float64
#  9   X10     78682 non-null  float64
#  10  X11     78682 non-null  float64
#  11  X12     78682 non-null  float64
#  12  X13     78682 non-null  float64
#  13  X14     78682 non-null  float64
#  14  X15     78682 non-null  float64
#  15  X16     78682 non-null  float64
#  16  X17     78682 non-null  float64
#  17  X18     78682 non-null  float64
# dtypes: float64(18)
# memory usage: 10.8 MB

# %%
x.head()
# Out:
#         X1       X2      X3      X4       X5      X6       X7        X8  \
# 0  511.267  833.107  18.373  89.031  336.018  35.163  128.348  372.7519
# 1  485.856  713.811  18.577  64.367  320.590  18.531  115.187  377.1180
# 2  436.656  526.477  22.496  27.207  286.588 -58.939   77.528  364.5928
# 3  396.412  496.747  27.172  30.745  259.954 -12.410   66.322  143.3295
# 4  432.204  523.302  26.680  47.491  247.245   3.504  104.661  308.9071
#
#          X9      X10      X11     X12      X13      X14      X15       X16  \
# 0  1024.333  740.998  180.447  70.658  191.226  163.816  201.026  1024.333
# 1   874.255  701.854  179.987  45.790  160.444  125.392  204.065   874.255
# 2   638.721  710.199  217.699   4.711  112.244  150.464  139.603   638.721
# 3   606.337  686.621  164.658   3.573  109.590  203.575  124.106   606.337
# 4   651.958  709.292  248.666  20.811  128.656  131.261  131.884   651.958
#
#        X17      X18
# 0  401.483  935.302
# 1  361.642  809.888
# ...

# %%
for column in x.columns:
    sns.boxplot(data=x[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(x)
x_new=scaler.transform(x)

# %%
y
# Out:
# 0        alive
# 1        alive
# 2        alive
# 3        alive
# 4        alive
#          ...
# 78677    alive
# 78678    alive
# 78679    alive
# 78680    alive
# 78681    alive
# Name: status_label, Length: 78682, dtype: object

# %%
y.unique()
# Out:
# array(['alive', 'failed'], dtype=object)

# %%
y_=y.replace({'alive':1,'failed':0})

# %%
y_.unique()
# Out:
# array([1, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
x_Train,x_Test,y_Train,y_Test=train_test_split(x_new,y_,train_size=0.9,random_state=42,shuffle=True)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier()

# %%
classifier.fit(x_Train,y_Train)
# Out:
# DecisionTreeClassifier()

# %%
yhat=classifier.predict(x_Test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix = confusion_matrix(y_Test, yhat)
class_report = classification_report(y_Test, yhat)

# %%
confusion_matrix
# Out:
# array([[  286,   782],
#        [  847, 13822]])

# %%
sns.heatmap(confusion_matrix)
# Out:
# <Axes: >

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.27      0.26      1068
#            1       0.95      0.94      0.94     14669
#
#     accuracy                           0.90     15737
#    macro avg       0.60      0.61      0.60     15737
# weighted avg       0.90      0.90      0.90     15737
